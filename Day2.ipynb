# %%
# Day 2 – Python Basics
## AI & ML Internship - Codomax Digital Solutions
### Intern: Ganesh Manikanta Reddy Yarram

# %%
name = "Ganesh"
age = 21
height = 5.8

print(name)
print(age)
print(height)
# Out:
# Ganesh
# 21
# 5.8

# %%
name = "Ganesh"      # String
age = 21             # Integer
height = 5.8         # Float
student = True       # Boolean

print(type(name))
print(type(age))
print(type(height))
print(type(student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
a = 20
b = 5

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
# Out:
# Addition: 25
# Subtraction: 15
# Multiplication: 100
# Division: 4.0
# Modulus: 0

# %%
name = input("Enter your name: ")
print("Welcome", name)
# Out:
# Enter your name:  ganesh reddy yarram
# Welcome ganesh reddy yarram

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("Eligible to Vote")
else:
    print("Not Eligible")
# Out:
# Enter your age:  21
# Eligible to Vote

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
count = 1

while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def greet(name):
    print("Hello", name)

greet("Ganesh")
# Out:
# Hello Ganesh

# %%
fruits = ["Apple", "Banana", "Mango"]

for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Banana
# Mango

# %%
numbers = (10,20,30)

print(numbers)
# Out:
# (10, 20, 30)

# %%
student = {
    "Name":"Ganesh",
    "Age":21,
    "Course":"AI & ML"
}

print(student)
# Out:
# {'Name': 'Ganesh', 'Age': 21, 'Course': 'AI & ML'}

# %%
text = "Python Programming"

print(text.upper())
print(text.lower())
print(len(text))
# Out:
# PYTHON PROGRAMMING
# python programming
# 18

# %% [markdown]
# # Expected Outcome
#
# Basic Python skills developed successfully.
#
# Topics Covered:
# - Variables
# - Data Types
# - Operators
# - Conditional Statements
# - Loops
# - Functions
# - Lists
# - Tuples
# - Dictionaries
# - String Operations
#
# Outcome:
# Successfully learned Python fundamentals by writing and executing simple Python programs.
