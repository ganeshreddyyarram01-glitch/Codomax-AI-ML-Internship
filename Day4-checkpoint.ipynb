# %%
import pandas as pd
#1.Load the student score dataset
df=pd.read_csv("student_scores.csv")
print("Dataset loaded sucessfully!")
# Out:
# Dataset loaded sucessfully!

# %%
#2.Explore Rows
print("\n--- Top 5 Rows---")
print(df.head())
# Out:
# --- Top 5 Rows---
#   Student  StudyHours  Score
# 0   Rahul           2     25
# 1   Priya           3     35
# 2    Bala           5     55
# 3  Ganesh           6     75
# 4   Kiran           7     70

# %%
print("\n--- Bottom 5Rows---")
print(df.tail())
# Out:
# --- Bottom 5Rows---
#    Student  StudyHours  Score
# 5  Raghava           8     80
# 6     Hima           9     88
# 7     Teja           4     45
# 8   Vikram           1     15
# 9   Mahesh          10     95

# %%
#3. Explore Dimensions and Column Information
print("\n--- Dataset Shape(Rows,Columns)---")
print(df.shape)
# Out:
# --- Dataset Shape(Rows,Columns)---
# (10, 3)

# %%
print("\n---Column Names---")
print(df.columns.tolist())
# Out:
# ---Column Names---
# ['Student', 'StudyHours', 'Score']

# %%
# 4. Explore Dataset Types and Summary Statistics
print("\n--- Summary Statistics ---")
print(df.describe())
# Out:
# --- Summary Statistics ---
#        StudyHours     Score
# count    10.00000  10.00000
# mean      5.50000  58.30000
# std       3.02765  27.54814
# min       1.00000  15.00000
# 25%       3.25000  37.50000
# 50%       5.50000  62.50000
# 75%       7.75000  78.75000
# max      10.00000  95.00000

# %% [markdown]
# 🚀 Day 4 Completed – Codomax AI/ML Internship
#
# Today I learned the fundamentals of Pandas for data analysis.
#
# ✅ Imported Pandas
# ✅ Loaded Student Score Dataset
# ✅ Explored Rows and Columns
# ✅ Checked Dataset Shape
# ✅ Viewed Dataset Information
# ✅ Generated Summary Statistics
#
# This task improved my understanding of handling datasets using Python and Pandas.
#
# Looking forward to Day 5 – Data Cleaning.
#
# #Codomax #Internship #AI #MachineLearning #Python #Pandas #DataScience #Learning
