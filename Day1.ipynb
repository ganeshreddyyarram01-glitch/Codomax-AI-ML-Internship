# %%
print("Hello, Codomax!")
print("AI & ML Internship")
print("Student Score Prediction Project")
print("Intern: Ganesh Manikanta Reddy Yarram")
# Out:
# Hello, Codomax!
# AI & ML Internship
# Student Score Prediction Project
# Intern: Ganesh Manikanta Reddy Yarram
